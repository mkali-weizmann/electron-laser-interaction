# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %matplotlib inline

# %% [markdown]
# # Note - the axes are in that order: $Z,X,Y,T$

# %%
A = np.load('Data Arrays\\Debugging Arrays\\A_1_both.npy')
plt.plot(A[:,0,0,0])
# plt.ylim(0, 2e-7)
# plt.plot(X[:, 0, 0, 0], Z[:, 0, 0, 0])
plt.show()

# %%
I_1 = np.load('Data Arrays\\Debugging Arrays\\phi_integrand_l_1.npy')[:, 0, 0, 0]
I_2 = np.load('Data Arrays\\Debugging Arrays\\phi_integrand_l_2.npy')[:, 0, 0, 0]
I_both = np.load('Data Arrays\\Debugging Arrays\\phi_integrand_both.npy')[:, 0, 0, 0]
I_cross_term = I_both - I_1 - I_2

fig, ax = plt.subplots(4, 1, figsize=(14, 14))
ax[0].plot(I_1, label="I_1")
ax[1].plot(I_2, label="I_2")
ax[2].plot(I_both, label="I_both")
ax[3].plot(I_cross_term, label="I_cross_term")
plt.legend()

# %%
A.shape
# Out:
# (1, 400, 400, 100)

# %%
import numpy as np
from microscope import *
x = np.linspace(-5e-6, 5e-6, 400)
z = x
t = np.linspace(-5e-16, 5e-16, 100)
y = np.array([0])
X, Y, Z, T = np.meshgrid(x, y, z, t)

A = gaussian_beam(x=X, y=Y, z=Z, E=1, lambda_laser=1064e-9, NA=0.05, t=T, mode='field', standing_wave=False, 
                  forward_propagation=True, imaginary=False)

def f(idx):
    fig, ax = plt.subplots(figsize=(14, 10))
    plt.imshow(np.abs(A[0, :, :, idx].T))
    plt.colorbar()


widgets.interact(f, idx=(0, A.shape[-1]-1, 1));
# Out:
# interactive(children=(IntSlider(value=49, description='idx', max=99), Output()), _dom_classes=('widget-interac…

# %%
A = np.load('Data Arrays\\Debugging Arrays\\A_1.npy')
def f(idx):
    fig, ax = plt.subplots(figsize=(14, 10))
    plt.imshow(np.abs(A[:, int(idx), :, 0].T))
    plt.colorbar()
    

widgets.interact(f, idx=(0, A.shape[1]-1, 1));
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=0), Output()), _dom_classes=('widget-interact'…

# %%
A = np.load('Data Arrays\\Debugging Arrays\\A_1_20.npy')
def f(t_idx):
    fig, ax = plt.subplots(figsize=(14, 10))
    plt.imshow(np.abs(A[A.shape[0]//2, :, :, int(t_idx)].T))
    plt.colorbar()
    plt.xlabel("x")
    plt.ylabel("z")
    

widgets.interact(f, t_idx=(0, A.shape[3]-1, 1));
# Out:
# interactive(children=(IntSlider(value=0, description='t_idx', max=0), Output()), _dom_classes=('widget-interac…

# %%
G = np.load('Data Arrays\\Debugging Arrays\\G.npy')
def f(t_idx):
    fig, ax = plt.subplots(figsize=(14, 6))
    plt.imshow(np.abs(G[:, G.shape[1]//2, :,int(t_idx)].T))
    plt.xlabel('x')
    plt.ylabel('z')
    plt.colorbar()

widgets.interact(f, t_idx=(0, G.shape[3]-1, 1));
# Out:
# interactive(children=(IntSlider(value=0, description='t_idx', max=0), Output()), _dom_classes=('widget-interac…

# %%
A = np.load('Data Arrays\\Debugging Arrays\\A.npy')
G = np.load('Data Arrays\\Debugging Arrays\\G.npy')
A_abs = np.abs(A[:, A.shape[1]//2, :, 0])
G_abs = np.abs(G[:, G.shape[1]//2, :, 0])
max_A_abs = np.max(A_abs)
max_G_abs = np.max(G_abs)


def f(x_idx):
    fig, ax = plt.subplots(2, 1, figsize=(14, 6))
    ax[0].plot(A_abs[int(x_idx), :], label='A')
    ax[0].set_ylim((0, max_A_abs))
    ax[0].legend()
    ax[0].set_title('A')
    ax[1].plot(G_abs[int(x_idx), :], label='G', color='orange')
    ax[1].set_ylim((0, max_G_abs))
    ax[1].legend()
    ax[1].set_title('G')

widgets.interact(f, x_idx=(0, G.shape[0]-1, 1));
# Out:
# interactive(children=(IntSlider(value=63, description='x_idx', max=127), Output()), _dom_classes=('widget-inte…

# %%
A = np.load('Data Arrays\\Debugging Arrays\\A.npy')
tan_alpha = np.tan(0.443)

fig, ax = plt.subplots(figsize=(14, 6))
plt.imshow(np.abs(A[:, A.shape[1]//2, :,1].T))
plt.xlabel("x")
plt.ylabel("z")
# plt.plot([0, 100e-6], [0, tan_alpha * 100e-6], color='red')
plt.colorbar();

# %%
G = np.load('Data Arrays\\Debugging Arrays\\G.npy')
fig, ax = plt.subplots(figsize=(14, 6))
plt.imshow(np.abs(G[:, G.shape[1]//2, :,0]))
plt.colorbar()
plt.xlabel("z")
plt.ylabel("x");

# %%
phi_values = np.load('Data Arrays\\Debugging Arrays\\phi.npy')
fig, ax = plt.subplots(figsize=(14, 6))
plt.imshow(np.abs(phi_values[:, :, 1]))
plt.colorbar()
plt.xlabel("z")
plt.ylabel("x")
# Out:
# Text(0, 0.5, 'x')

# %%
phi_values = np.load('Data Arrays\\Debugging Arrays\\phi.npy')
def f(t_idx):
    fig, ax = plt.subplots(figsize=(14, 6))
    plt.plot(np.abs(phi_values[:, phi_values.shape[1]//2, int(t_idx)].T))
#     plt.colorbar()

widgets.interact(f, t_idx=(0, phi_values.shape[2]-1, 1));
# Out:
# interactive(children=(IntSlider(value=1, description='t_idx', max=2), Output()), _dom_classes=('widget-interac…

# %%
phi_values = np.load('Data Arrays\\Debugging Arrays\\phi.npy')
phase_mask = np.exp(1j * phi_values)
PHASE_MASK = np.fft.fft(phase_mask, axis=2, norm='forward')

def f(x_idx):
    fig, ax = plt.subplots(2, 1, figsize=(14, 6))
    ax[0].plot(phi_values[x_idx, phi_values.shape[1]//2, :])
    ax[1].plot(np.abs(PHASE_MASK[x_idx, PHASE_MASK.shape[1]//2, :]))

def g(x_idx):
    fig, ax = plt.subplots(figsize=(14, 6))
    ax.plot(np.angle(phase_mask[x_idx, phi_values.shape[1]//2, :]))
    
def h(angle=0):
    x_real = np.arange(phase_mask.shape[2])
    y = phase_mask[phase_mask.shape[0] // 2, phase_mask.shape[1] // 2, :]
    y_real = np.real(y)
    y_image = np.imag(y)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot(x_real, y_real, y_image)
    ax.plot([x_real[0], x_real[-1]], [0, 0], [0, 0], linestyle='-')
    ax.set_xlabel('t')
    ax.set_ylabel('y_real')
    ax.set_zlabel('y_imag')
    ax.set_ylim((-1.1, 1.1))
    ax.set_zlim((-1.1, 1.1))
    ax.view_init(30, angle)
    plt.show()

# widgets.interact(f, x_idx=(0, phase_mask.shape[0]-1, 1));
# widgets.interact(g, x_idx=(0, phi_values.shape[0]-1, 1));
widgets.interact(h, angle=(0, 360, 1));
# Out:
# interactive(children=(IntSlider(value=0, description='angle', max=360), Output()), _dom_classes=('widget-inter…

# %%
fig, ax = plt.subplots(figsize=(14, 14))
phi_values = np.load('Data Arrays\\Debugging Arrays\\phi_values.npy')
phase_mask = np.exp(1j * phi_values)
PHASE_MASK = np.fft.fft(phase_mask, axis=2, norm='forward')
plt.plot(np.abs(PHASE_MASK[PHASE_MASK.shape[0]//2, PHASE_MASK.shape[1]//2, 0:20]))
print(f"Amplitude of the zero'th frequency: {np.abs(PHASE_MASK[0,0,0])**2}")
# Out:
# Amplitude of the zero'th frequency: 0.9954350902082253

# %%
M = np.load('Data Arrays\\Debugging Arrays\\phase_amplitude_mask.npy')
fig, ax = plt.subplots(1, 2, figsize=(14, 7))
im1 = ax[0].imshow(np.abs(M));
im2 = ax[1].imshow(np.angle(M));
plt.colorbar(im1, ax=ax[0])
plt.colorbar(im2, ax=ax[1])
ax[0].set_title("abs")
ax[1].set_title("angle");

# %%
import numpy as np

a = np.ones((10000, 2000))
b = np.ones((2000, 10000))
# %timeit np.sum(a, axis=0)
# 27.6 ms ± 541 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# %timeit  np.sum(b, axis=-1)
# 34.6 ms ± 876 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Out:
# 17.6 ms ± 449 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 29.1 ms ± 265 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
